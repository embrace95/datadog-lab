# %%
import sys
import os
import json
import importlib

# Extend path to project root so Python can find scripts/
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# ✅ Import the *full module* so we can inspect it
import scripts.invoke_model as im
importlib.reload(im)
# 🔍 Confirm we’re loading the right file
print("Script path being used:", im.__file__)
response = im.invoke_bedrock("explain_k8s")
print(response)
# Out:
# Script path being used: /home/sunny/datadog-lab/bedrock-lab/scripts/invoke_model.py
# 🔍 Looking for prompts at: /home/sunny/datadog-lab/bedrock-lab/config/prompts.json
#  Kubernetes provides SREs with a platform to easily deploy and manage containerized applications at scale. It allows SREs to automate routine tasks like provisioning, updating, and scaling infrastructure to meet fluctuating user demand. Kubernetes handles tasks like replication, load balancing, and healing of services which frees up SREs to focus on higher level concerns. Its declarative model lets SREs define their desired application state and Kubernetes ensures the actual state matches. This makes infrastructure highly available and reliable with minimal manual intervention.
